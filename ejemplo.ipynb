# %%
nombre = Aldo
edad = 21
es_estudiante = True

print(type nombre)
print(type edad)
# Out:
#   Cell In[9], line 5
#     print(type nombre)
#                ^
# SyntaxError: invalid syntax

# %%
print("Aldo")
# Out:
# Aldo

# %%
En este punto inicialize el proyecto en Git

# %%
Algortimo para calcular velocidad

# %%
distancia input("Ingrese la distancia en kilometros: ")
tiempo = input("Ingrese el tiempo en horas:")

velocidad = distancia / tiempo

print
# Out:
#   Cell In[1], line 1
#     distancia input("Ingrese la distancia en kilometros: ")
#               ^
# SyntaxError: invalid syntax

# %%
distancia = input("Ingrese la distancia en kilometros: ")
tiempo = input("Ingrese el tiempo en horas:")

print("El dato distancia es de tipo:", type(distancia))
print("El dato tiempo es de tipo:", type(tiempo))

velocidad = distancia / tiempo

print("La velocidad promedio es:", velocidad)

# %%
El dato distancia es de tipo: <class 'str'>
El dato tiempo es de tipo: <class 'int'>
La velocidad promedio es de: 40.0

# %%
Operadores

# %%
a = 4
b = 6

print(a+b)
print(a < b)
print(a != b)
# Out:
# 10
# True
# True

# %%
edad_str = input("Ingrese su edad:")
nombre_str = input("Ingrese su nombre:")

print("Hola", nombre_str, "tienes", edad_str, "años")
# Out:
# Hola Aldo tienes 21 años
